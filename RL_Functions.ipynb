# %% [markdown]
# # RL FUNCTIONS VINGETTE

# %% [markdown]
# ### Authors: Karam Mukhtar, Pranay Lolabattu

# %% [markdown]
# #### Part 1A: Modified Levenstein distance measurement.

# %%
# %%time
import stringdist
import numpy as np
import threading
from fuzzywuzzy import fuzz

def levenstein(seq1, seq2):
    distances = []
    for i in range(len(seq1)):
        a = seq1[i]
        b = seq2[i]
        max_len = max(len(a), len(b))
        distances.append((max_len - stringdist.levenshtein(a, b)) / max_len)
    return distances

def lev_single(a, b):
    max_len = max(len(a), len(b))
    return (max_len - stringdist.levenshtein(a, b)) / max_len 
#test:
s_1 = ['antelope', 'koor', 'croatia']
s_2 = ['jakarta', 'roo', 'lithuania']
levenstein(s_1, s_2)
# Out:
# Wall time: 333 ms
# C:\Users\Karam\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# #### Part 1B: Find The Indices of missing values in the dataframe

# %%
# %%time
import pandas as pd

#create pandas dataframes with our data
S1 = pd.read_csv('S1.csv') 
S2 = pd.read_csv('S2.csv')

#Takes in a pandas dataframe and returns a dictionary mapping column names to the missing value indices for that column
def missing_value_indices(df): #df is a pandas dataframe with columns such as first name, last name, DOB, sex, etc.
    index_dict = {}
    columns = df.columns #names of each of the columns in the dataframe i.e. 'sex'
    for i in columns:
        index_dict[i] = list(df[i][df[i].isna()].index)
    return index_dict
# Out:
# Wall time: 577 ms

# %% [markdown]
# #### Part 1C: Find the Indices of all unique values in the Dataframe

# %%
# %%time
# A dataframe has to be made before passing it into the function. simply name the dataframe and then insert that name into the paranthesis of the function unique.
def unique(dataframe):
    df_dict = {}
    for column in dataframe.columns:
        df_dict[column] = {}
        for i in np.arange(len(dataframe[column])):
            value = dataframe[column].get(i)
            if value in df_dict[column]:
                df_dict[column][value] += [i]
            else:
                df_dict[column][value] = []
                df_dict[column][value] += [i]
    return df_dict
print(unique(S1))
# Out:
# {'sex': {0: [0, 3, 4, 5, 8, 9, 12, 15, 16, 19, 21, 23, 25, 26, 29, 30, 32, 35, 39, 41, 42, 43, 44, 46, 51, 52, 53, 55, 57, 58, 62, 65, 66, 67, 68, 70, 71, 73, 74, 76, 77, 79, 81, 82, 83, 84, 85, 86, 89, 91, 92, 93, 97, 99, 101, 102, 103, 104, 105, 106, 109, 110, 111, 116, 117, 119, 120, 121, 123, 125, 126, 128, 131, 132, 134, 136, 137, 138, 139, 143, 144, 148, 151, 152, 153, 154, 155, 156, 158, 159, 161, 162, 163, 164, 166, 168, 170, 173, 176, 177, 179, 186, 188, 191, 192, 193, 194, 195, 196, 199, 203, 204, 206, 208, 209, 210, 219, 221, 222, 224, 226, 228, 233, 234, 235, 237, 240, 242, 246, 248, 252, 253, 254, 255, 256, 257, 259, 263, 273, 281, 285, 286, 288, 290, 292, 299, 300, 301, 302, 303, 304, 310, 312, 313, 316, 317, 321, 322, 323, 324, 325, 326, 327, 330, 331, 334, 335, 337, 338, 341, 342, 344, 345, 346, 349, 353, 356, 357, 358, 365, 367, 368, 369, 370, 375, 376, 377, 379, 382, 383, 387, 388, 390, 392, 394, 395, 396, 397, 399, 400, 402, 403, 405, 406, 411, 412, 414, 418
, 1330, 1334, 1335, 1337, 1340, 1341, 1343, 1345, 1348, 1350, 1352, 1353, 1354, 1355, 1357, 1362, 1365, 1369, 1371, 1373, 1375, 1379, 1380, 1381, 1382, 1383, 1385, 1390, 1393, 1395, 1404, 1405, 1406, 1407, 1411, 1412, 1420, 1421, 1426, 1427, 1429, 1430, 1432, 1435, 1437, 1438, 1439, 1440, 1442, 1444, 1446, 1448, 1450, 1451, 1452, 1454, 1456, 1458, 1462, 1464, 1465, 1466, 1467, 1468, 1469, 1471, 1473, 1474, 1475, 1477, 1478, 1482, 1 ...
# Wall time: 1.2 s

# %% [markdown]
# #### Part 1D: pylib2 and FClib2

# %%
# %%time
pylib2 = pd.read_csv('pylib2.csv')
pylib_dict = {}
for i in np.arange(pylib2.shape[0]):
    if ',' in pylib2['values'][i]:
        pylib_dict[pylib2['ind'][i]] = '[' + pylib2['values'][i] + ']'
    else:
        pylib_dict[pylib2['ind'][i]] = pylib2['values'][i]

def str_to_py(input):
    a = list(input)
    result_list = [pylib_dict[i] if i in pylib_dict else i for i in a]
    return ''.join(result_list)

def list_to_py(input):
    return [str_to_py(i) for i in input]
# Out:
# Wall time: 916 ms

# %%
# %%time
FClib2 = pd.read_csv('FClib2.csv')
FC_dict = {}
for i in np.arange(FClib2.shape[0]):
    FC_dict[FClib2['ind'][i]] = FClib2['values'][i]

def str_to_FC(input):
    a = list(input)
    result_list = [FC_dict[i] if i in FC_dict else i for i in a]
    return ''.join(result_list)

def list_to_FC(input):
    return [str_to_FC(i) for i in input]
# Out:
# Wall time: 2.62 s

# %% [markdown]
# #### Part 1E: A Function that removes all the elements inside the inputted variable lst (which is of list type) from the inputted string variable.

# %%
# %%time
def remove_any_from_str(string, lst):
    for i in string:
        if i in lst:
            string = string.replace(i, '')
    return string
# Out:
# Wall time: 0 ns

# %%
remove_any_from_str("alphabetic", ['a', 'b', 'c'])
# Out:
# 'lpheti'

# %% [markdown]
#  #### Part 1F: building the sparse martrix.

# %%
# %%time
def build_sparse_matrix(list1, list2):
    df = pd.DataFrame()
    df['index'] = list1
    for i in list2:
        df[i] = [1 if i == j else 0 for j in df['index'].tolist()]
    df.set_index('index', inplace=True)
    return df
# Out:
# Wall time: 0 ns

# %%
# %%time
def compare_unique(list1, list2, sim_func):
    sim_dict = {}
    for i in list1:
        for j in list2:
            comparison = sim_func(i, j)
            if comparison in sim_dict:
                sim_dict[comparison].add((i, j))
            else:
                sim_dict[comparison] = set()
                sim_dict[comparison].add((i, j))
    return sim_dict
# Out:
# Wall time: 0 ns

# %% [markdown]
# #### Part 2A: Building the sparse matrix for each column in the dataframe:
# * This function takes in 5 variables 2 lists of unique values corrisponding to the 2 dataframes S1 and S2.
# * sim variable which corrispondes to the method of measuring the similarity of the strings, all of the following examples employ the use of the fuzz.ratio() funtion from the fuzzywuzzy library which must be installed prior to importing.
# * threshold represents the threshold value for the similarity calculation. In otherwords the degree of similarity above which all values will be considered matching.
# * indices_1 and indices_2 represent the indices corresponding to the unique values inside all of the columns.

# %%
def build_sparse_from_sim(unique_1, unique_2, sim, threshold, indices_1, indices_2):
    result = set()
    for i in unique_1:
        for j in unique_2:
            if sim(i, j) >= threshold:
                for a in indices_1[i]:
                    for b in indices_2[j]:
                        result.add((a, b))
    return result

# %% [markdown]
# #### Part 2B: Unique dictionary functions that return dictionary class items of the unique variables and their indices

# %%
# %%time
unique_dict_1 = unique(S1)
unique_dict_2 = unique(S2)
print(type(unique_dict_1))
# Out:
# <class 'dict'>
# Wall time: 2.84 s

# %%
# %%time
a = np.unique(S1['lname.py'].tolist())
b = np.unique(S2['lname.py'].tolist())
c = fuzz.ratio
d = 85
e = unique_dict_1['lname.py']
f = unique_dict_2['lname.py']
# Out:
# ['[bai4,bai5]' '[bao4,bao1]' '[bian5,bian1]' '[bie4,bie2]' '[bin1,bang1]'
#  '[bo2,bo5]' '[bo5,bu3]' '[bu5,bu3]' '[chong2,zhong4]' '[chong4,chong1]'
#  '[chuang3,chen4]' '[chuang4,cang1]' '[dang5,dang1]' '[de5,di4]'
#  '[diao4,diao5]' '[ding5,ding1]' '[du2,dou4]' '[feng1,fan2]' '[fu2,fei4]'
#  '[fu5,fu4]' '[gan4,gan1]' '[ge3,gai4]' '[guan4,guan1]' '[guang4,an1]'
#  '[guo5,guo1]' '[he2,he4]' '[heng2,geng4]' '[heng4,heng2]' '[hong2,gong1]'
#  '[hu5,hu4]' '[hua4,hua1]' '[huan4,huan1]' '[huan5,huan1]' '[ji3,ji1]'
#  '[ji5,ji3]' '[jia3,gu3]' '[jian4,jian1]' '[jie5,ji4]' '[ju1,che1]'
#  '[ju4,ju1]' '[jue2,jiao4]' '[kuai4,hui4]' '[lan5,lan2]' '[li3,feng1]'
#  '[ling2,ling1]' '[ling5,ling2]' '[lu4,liu4]' '[lu5,lu2]' '[luo4,jia4]'
#  '[luo5,luo1]' '[lv4,lu4]' '[mai5,mai4]' '[mang2,long2]' '[mao2,mao1]'
#  '[mi3,er3]' '[mi4,jiao3]' '[mo2,me5]' '[mo4,mei2]' '[mou2,miao4]'
#  '[nan5,nan2]' '[nei4,na4]' '[ni2,er2]' '[ning4,ning2]' '[pan5,pan2]'
#  '[pei2,fei2]' '[ping2,feng2]' '[po1,bo1]' '[pu3,pu2]' '[qi2,ji4]'
#  '[qian3,jian1]' '[qian5,qian2]' '[qing4,qin1]' '[qiu1,gui1]'
#  '[shan4,chan2]' '[shan5,shan3]' '[shang1,tang1]' '[sheng4,sheng1]'
#  '[shuang1,long2]' '[ta4,da2]' '[tai5,tai2]' '[tan1,han4]' '[tan5,dan4]'
#  '[tang1,shang1]' '[tou5,tou2]' '[wan1,guan1]' '[wei3,hua1]' '[wen4,wen2]'
#  '[wo3,rui2]' '[wo5,wo1]' '[wu2,mo2]' '[wu5,e3]' '[xi5,xi4]'
#  '[xian4,xian2]' '[xiang4,xiang1]' '[xiang5,xiang4]' '[xing5,xing1]'
#  '[xu3,hu3]' '[xuan1,xian4]' '[xun4,sun1]' '[ya1,wu1]' '[ya4,ya1]'
#  '[yan3,yan2]' '[yan4,yan2]' '[yao1,miao4]' '[yao2,diao4]' '[yao5,shuo4]'
#  '[yi3,yi1]' '[yi4,yi2]' '[yin4,yin1]' '[yin4,yin3]' '[ying5,ying1]'
#  '[you3,you4]' '[yu2,wu2]' '[yu4,yu2]' '[yuan3,wei3]' '[yuan4,yuan3]'
#  '[yue1,yao1]' '[yue4,le4]' '[zai4,zai3]' '[ze2,shi4]' '[zeng1,ceng2]'
#  '[zhan5,zhan4]' '[zhang3,chang2]' '[zhao4,diao4]' '[zhen1,qian2]'
#  '[zhen3,dian1]' '[zhen4,chen2]' '[zhen4,zhen1]' '[zheng4,zheng1]'
#  '[zhi4,zhi1]' '[zhong3,zhong4]' '[zhong4,zhong3]' '[zhong5,zhong1]'
#  '[zhou1,zou1]' '[zhu1,zou1]' '[zhuan1,tuan2]' '[zhun3,chun2]'
#  '[zou1,ju4]' '[zu1,chu2]' 'a1' 'ai1' 'ai4' 'an1' 'an3' 'an4' 'ang2' 'ao2'
#  'ao4' 'ba1' 'ba2' 'bai2' 'bai3' 'ban1' 'ban3' 'bang1' 'bao1' 'bao2'
#  'bao3' 'bao4' 'bei1' 'bei3' 'bei4' 'ben1' 'ben3' 'bi3' 'bi4' 'bian1'
#  'bian3' 'bian4' 'bin1' 'bing1' 'bing4' 'bo1' 'bo2' 'bu3' 'bu4' 'cai2'
#  'cai3' 'cai4' 'cang1' 'cang2' 'cao2' 'cao3' 'cen2' 'ceng2' 'cha2' 'chai2'
#  'chan3' 'chan4' 'chang1' 'chang2' 'chang4' 'chao1' 'chao2' 'che1' 'chen2'
#  'cheng2' 'chi1' 'chi2' 'chi4' 'chong2' 'chou2' 'chu1' 'chu2' 'chu3'
#  'chu4' 'chuan1' 'chuan2' 'chuan4' 'chui1' 'chun1' 'chun2' 'cong2' 'cou4'
#  'cui1' 'cun1' 'cuo4' 'da2' 'da3' 'da4' 'dai4' 'dan1' 'dang1' 'dao1'
#  'dao3' 'dao4' 'de2' 'deng1' 'deng3' 'deng4' 'di1' 'di2' 'di3' 'di4'
#  'dian4' 'diao1' 'ding1' 'ding4' 'diu1' 'dong1' 'dong3' 'dou1' 'dou4'
#  'du2' 'du3' 'du4' 'duan1' 'duan4' 'dun1' 'duo1' 'duo3' 'e2' 'e4' 'en1'
#  'er2' 'er3' 'er4' 'fa3' 'fan2' 'fan3' 'fan4' 'fang1' 'fang2' 'fang4'
#  'fei1' 'fei3' 'fei4' 'fen1' 'feng1' 'feng2' 'feng4' 'fo2' 'fu2' 'fu3'
#  'fu4' 'gai1' 'gai4' 'gan1' 'gan3' 'gan4' 'gang1' 'gang3' 'gao1' 'ge1'
#  'ge2' 'ge3' 'geng1' 'geng3' 'gong1' 'gong4' 'gou1' 'gu1' 'gu3' 'gu4'
#  'gua4' 'guan1' 'guan3' 'guan4' 'guang1' 'guang3' 'gui1' 'gui3' 'gui4'
#  'gun3' 'gun4' 'guo1' 'guo2' 'ha1' 'hai3' 'han2' 'han3' 'han4' 'hao3'
#  'hao4' 'he2' 'he4' 'hei1' 'heng1' 'heng2' 'hong2' 'hou2' 'hou3' 'hou4'
#  'su1' 'su4' 'suan4' 'sui1' 'sui4' 'sun1' 'suo1' 'suo3' 'ta3' 'tai2'
#  'tai4' 'tan2' 'tan3' 'tang2' 'tao2' 'te4' 'teng2' 'ti2' 'ti4' 'tian1'
#  'tian2' 'tie1' 'tie3' 'ting2' 'tong1' 'tong2' 'tong5' 'tou2' 'tu1' 'tu2'
#  'tu3' 'tui4' 'tuo1' 'tuo3' 'tuo4' 'wa1' 'wan2' 'wan4' 'wang1' 'wang2'
#  'wang3' 'wang4' 'wei1' 'wei2' 'wei3' 'wei4' 'wen1' 'wen2' 'weng1' 'wo1'
#  'wo3' 'wo4' 'wu1' 'wu2' 'wu3' 'wu4' 'xi1' 'xi2' 'xi3' 'xi4' 'xia4'
#  'xian1' 'xian2' 'xian3' 'xiang1' 'xiang2' 'xiang4' 'xiao1' 'xiao3'
#  'xiao4' 'xie2' 'xie4' 'xin1' 'xin4' 'xing1' 'xing2' 'xing4' 'xiong1'
#  'xiong2' 'xiu3' 'xiu4' 'xu1' 'xu2' 'xu3' 'xu4' 'xuan1' 'xuan2' 'xuan4'
#  'xue1' 'xue3' 'xun1' 'xun2' 'ya1' 'ya3' 'ya4' 'yan2' 'yan3' 'yan4'
#  'yang2' 'yang3' 'yao2' 'yao4' 'ye1' 'ye3' 'ye4' 'yi1' 'yi2' 'yi3' 'yi4'
#  'yin1' 'yin2' 'yin3' 'yin4' 'ying1' 'ying2' 'yong1' 'yong3' 'you1' 'you2'
#  'you3' 'you4' 'you5' 'yu1' 'yu2' 'yu3' 'yu4' 'yuan1' 'yuan2' 'yuan3'
#  'yuan4' 'yue1' 'yue4' 'yun2' 'yun4' 'za2' 'zai3' 'zai4' 'zan2' 'zan4'
#  'zang1' 'zao1' 'zao3' 'ze2' 'zeng1' 'zha1' 'zha2' 'zhai1' 'zhai2' 'zhan1'
#  'zhan4' 'zhang1' 'zhang3' 'zhao1' 'zhao4' 'zhe1' 'zhe2' 'zhe3' 'zhen1'
#  'zhen3' 'zheng1' 'zheng4' 'zhi1' 'zhi2' 'zhi3' 'zhi4' 'zhong1' 'zhong3'
#  'zhong4' 'zhou1' 'zhou5' 'zhu1' 'zhu2' 'zhu3' 'zhu4' 'zhuan1' 'zhuang1'
#  'zhui1' 'zhuo2' 'zi1' 'zi3' 'zi4' 'zong1' 'zong3' 'zou1' 'zu2' 'zu3'
#  'zui4' 'zun1' 'zuo3' 'あ' 'お' 'か' 'き' 'く' 'こ' 'た' 'つ' 'ひ' 'ほ' 'ま' 'み' 'む'
#  'も' 'ゆ' 'オ' 'キ' 'コ' 'ザ' 'ス' 'ト' 'ヤ' 'ユ' '䓕' '塩' '壱' '広' '桜' '榊' '渋' '畑'
#  '笹' '絵' '釈' '靏' '麿' '김' '박' '성' '윤' '이']
# Wall time: 13 ms

# %%
# %%time
last_names = build_sparse_from_sim(a, b, c, d, e, f)
# Out:
# Wall time: 14.3 s

# %%
# %%time
fname_S1 = []
for i in S1['fname.py']:
    if isinstance(i,str):
        fname_S1.append(i)
fname_S2 = []
for i in S2['fname.py']:
    if isinstance(i,str):
        fname_S2.append(i)

while len(S1) > len(fname_S1):
    fname_S1.append('0')
while len(S2) > len(fname_S2):
    fname_S2.append('0')

fname_new1 = pd.DataFrame({'fname_fixed':fname_S1})
fname_new2 = pd.DataFrame({'fname_fixed':fname_S2})

S1 = S1.join(fname_new1)
S2 = S2.join(fname_new2)
# Out:
# Wall time: 14 ms

# %%
# %%time
a = np.unique(fname_S1)
b = np.unique(fname_S2)
c = fuzz.ratio
d = 85
e = unique(fname_new1).get('fname_fixed')
f = unique(fname_new2).get('fname_fixed')
# Out:
# Wall time: 221 ms

# %%
# %%time
first_name = build_sparse_from_sim(a, b, c, d, e, f)
# Out:
# Wall time: 17min 22s

# %%
# %%time
def exact_match(a, b):
    if a == b:
        return 1
    return 0

a = np.unique(S1['sex'].tolist())
b = np.unique(S2['sex'].tolist())
c = exact_match
d = 1
e = unique_dict_1['sex']
f = unique_dict_2['sex']
# Out:
# Wall time: 4.99 ms

# %%
# %%time
sex = build_sparse_from_sim(a, b, c, d, e, f)
# Out:
# <class 'set'>
# Wall time: 13.6 s

# %%
# %%time
a = np.unique(S1['yob'].tolist())
b = np.unique(S2['yob'].tolist())
c = exact_match
d = 1
e = unique_dict_1['yob']
f = unique_dict_2['yob']

yobs = build_sparse_from_sim(a, b, c, d, e, f)
# Out:
# Wall time: 627 ms

# %%
# %%time
a = np.unique(S1['mob'].tolist())
b = np.unique(S2['mob'].tolist())
c = exact_match
d = 1
e = unique_dict_1['mob']
f = unique_dict_2['mob']

mobs = build_sparse_from_sim(a, b, c, d, e, f)
# Out:
# Wall time: 2.03 s

# %%
# %%time
a = np.unique(S1['dob'].tolist())
b = np.unique(S2['dob'].tolist())
c = exact_match
d = 1
e = unique_dict_1['dob']
f = unique_dict_2['dob']

dobs = build_sparse_from_sim(a, b, c, d, e, f)
# Out:
# Wall time: 712 ms

# %% [markdown]
# **DEMO STARTS HERE**

# %%
# %%time
ls = []
i = 0
j = 0
for i in range(0,len(S1)):
    for j in range(0,len(S2)):
        ls.append((i,j))
# Out:
# Wall time: 28 s

# %%
# %%time
lsy = []
for i in ls:
    if i in yobs:
        lsy.append(1)
    else:
        lsy.append(0)
# Out:
# Wall time: 42.6 s

# %%
# %%time
lsm = []
for i in ls:
    if i in mobs:
        lsm.append(1)
    else:
        lsm.append(0)
# Out:
# Wall time: 50.7 s

# %%
# %%time
lsd = []
for i in ls:
    if i in dobs:
        lsd.append(1)
    else:
        lsd.append(0)
# Out:
# Wall time: 45.1 s

# %%
# %%time
lsx = []
for i in ls:
    if i in sex:
        lsx.append(1)
    else:
        lsx.append(0)
# Out:
# Wall time: 2min 6s
# Parser   : 2.01 s

# %%
# %%time
lsn = []
for i in ls:
    if i in last_names:
        lsn.append(1)
    else:
        lsn.append(0)
# Out:
# Wall time: 49.1 s

# %%
# %%time
lsf = []
for i in ls:
    if i in first_name:
        lsf.append(1)
    else:
        lsf.append(0)
# Out:
# Wall time: 40.3 s

# %% [markdown]
# ## **END**

# %%
# %%time
df_master = pd.DataFrame({"Indices":ls, "L.names":lsn, "F.names":lsf, "Sex":lsx, "Dob":lsd, "Mob":lsm, "Yob":lsy})
# Out:
# Wall time: 2min 46s

# %%
# %%time
df_master.set_index('Indices', inplace=True)
df_master
# Out:
# Wall time: 1.56 s

# %%
# %%time
dfm = df_master.values
list(df_master.columns.values)
# Out:
# Wall time: 997 µs

# %%
# %%time
unique_rows, counts = np.unique(dfm, return_counts = True, axis=0)
unique_rows = unique_rows.view(dfm.dtype).reshape(-1, dfm.shape[1])

dfm2 = pd.DataFrame(unique_rows, columns = [df_master.columns.values])

counts = pd.DataFrame(counts, columns = ['counts'])
print(dfm2.join(counts))
# Out:
#     (L.names,)  (F.names,)  (Sex,)  (Dob,)  (Mob,)  (Yob,)    counts
# 0            0           0       0       0       0       0  26617977
# 1            0           0       0       0       0       1    779136
# 2            0           0       0       0       1       0   2413021
# 3            0           0       0       0       1       1     70875
# 4            0           0       0       1       0       0    884844
# 5            0           0       0       1       0       1     26091
# 6            0           0       0       1       1       0     80650
# 7            0           0       0       1       1       1      2261
# 8            0           0       1       0       0       0  26612839
# 9            0           0       1       0       0       1    779484
# 10           0           0       1       0       1       0   2417676
# 11           0           0       1       0       1       1     70407
# 12           0           0       1       1       0       0    884472
# 13           0           0       1       1       0       1     25808
# 14           0           0       1       1       1       0     80384
# 15           0           0       1       1       1       1      5255
# 16           0           1       0       0       0       0      9230
# 17           0           1       0       0       0       1       255
# 18           0           1       0       0       1       0       852
# 19           0           1       0       0       1       1        28
# 20           0           1       0       1       0       0       334
# 21           0           1       0       1       0       1         9
# 22           0           1       0       1       1       0        26
# 23           0           1       1       0       0       0      9378
# 24           0           1       1       0       0       1       292
# 25           0           1       1       0       1       0       808
# 26           0           1       1       0       1       1        19
# 27           0           1       1       1       0       0       325
# 28           0           1       1       1       0       1        12
# 29           0           1       1       1       1       0        20
# 30           0           1       1       1       1       1         9
# 31           1           0       0       0       0       0    197046
# 32           1           0       0       0       0       1      5827
# 33           1           0       0       0       1       0     18139
# 34           1           0       0       0       1       1       535
# 35           1           0       0       1       0       0      6564
# 36           1           0       0       1       0       1       191
# 37           1           0       0       1       1       0       570
# 38           1           0       0       1       1       1        70
# 39           1           0       1       0       0       0    197697
# 40           1           0       1       0       0       1      5714
# 41           1           0       1       0       1       0     18174
# 42           1           0       1       0       1       1       522
# 43           1           0       1       1       0       0      6491
# 44           1           0       1       1       0       1       227
# 45           1           0       1       1       1       0       678
# 46           1           0       1       1       1       1      4743
# 47           1           1       0       0       0       0       139
# 48           1           1       0       0       0       1         6
# 49           1           1       0       0       1       0        13
# 50           1           1       0       0       1       1         1
# 51           1           1       0       1       0       0         1
# 52           1           1       0       1       0       1         1
# 53           1           1       0       1       1       0         1
# 54           1           1       1       0       0       0       156
# 55           1           1       1       0       0       1         3
# 56           1           1       1       0       1       0        15
# 57           1           1       1       1       0       0         6
# 58           1           1       1       1       1       0         1
# 59           1           1       1       1       1       1        13
# Wall time: 3min 56s

# %%
import multiprocessing
print("Processor Core Count: ", multiprocessing.cpu_count())
# Out:
# Processor Core Count:  8
